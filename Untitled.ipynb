# %%
import pandas as pd
import numpy as np
import json

# %%
def player_dictionary():
    '''
    Data source: https://any-api.com/nba_com/nba_com/console/_commonallplayers/GET
    Actual URL: (https://stats.nba.com/stats/commonallplayers?LeagueID=00&Season=2019-20&IsOnlyCurrentSeason=0)
    Resource: https://any-api.com:8443/https://stats.nba.com/stats/commonallplayers?LeagueID=00&Season=2019-20&IsOnlyCurrentSeason=0
    '''
    with open('data/totalPlayerIDs.json') as f:
        j = json.loads(f.read())
        headers = j['resultSets'][0]['headers']
        player_ids = j['resultSets'][0]['rowSet']
        nba_players = pd.DataFrame(player_ids, columns=headers)
        nba_players.to_csv('data/NBA_Player_Dictionary.csv', index=False)
    return pd.read_csv('data/NBA_Player_Dictionary.csv')

# %%
nba_player_dict = player_dictionary()

# %%
nba_player_dict[['Hervey' in i for i in nba_player_dict['DISPLAY_FIRST_LAST']]]
# Out:
#       PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 1739    1628987            Hervey, Kevin       Kevin Hervey             1
#
#      FROM_YEAR TO_YEAR    PLAYERCODE     TEAM_ID      TEAM_CITY TEAM_NAME  \
# 1739      2019    2019  kevin_hervey  1610612760  Oklahoma City   Thunder
#
#      TEAM_ABBREVIATION TEAM_CODE GAMES_PLAYED_FLAG OTHERLEAGUE_EXPERIENCE_CH
# 1739               OKC   thunder                 N                        11

# %%
fd_players = pd.read_csv('data/FanDuel-NBA-2019-12-16-41696-players-list.csv')

# %%
fd_players
# Out:
#                Id Position First Name               Nickname      Last Name  \
# 0      41696-9644       SG      James           James Harden         Harden
# 1     41696-40199       SF    Giannis  Giannis Antetokounmpo  Antetokounmpo
# 2     41696-84669       PG       Luka            Luka Doncic         Doncic
# 3     41696-15595       SG    Bradley           Bradley Beal           Beal
# 4      41696-9642       PG    Russell      Russell Westbrook      Westbrook
# ..            ...      ...        ...                    ...            ...
# 225  41696-116202       PG      Jalen           Jalen Lecque         Lecque
# 226   41696-58350       SF    Stanley        Stanley Johnson        Johnson
# 227    41696-9715       SG      Marco        Marco Belinelli      Belinelli
# 228   41696-63478        C  Cristiano      Cristiano Felicio        Felicio
# 229    41696-9725       SF       C.J.             C.J. Miles          Miles
#
#           FPPG  Played  Salary     Game Team Opponent Injury Indicator  \
# 0    60.484614      26   12400   SA@HOU  HOU       SA              NaN
# 1    58.188462      26   12100  DAL@MIL  MIL      DAL              NaN
# 2    53.672002      25   11900  DAL@MIL  DAL      MIL                O
# 3    43.825002      24   10500  WAS@DET  WAS      DET              NaN
# 4    44.752176      23   10400   SA@HOU  HOU       SA              NaN
# ..         ...     ...     ...      ...  ...      ...              ...
# 225   0.000000       0    3500  POR@PHO  PHO      POR              NaN
# 226   2.880000       5    3500  CLE@TOR  TOR      CLE                O
# 227   9.852174      23    3500   SA@HOU   SA      HOU              NaN
# 228   9.635000      60    3500  CHI@OKC  CHI      OKC              GTD
# 229  13.439999      10    3500  WAS@DET  WAS      DET                O
#
#     Injury Details  Tier  Unnamed: 14  Unnamed: 15
# 0              NaN   NaN          NaN          NaN
# 1              NaN   NaN          NaN          NaN
# 2            Ankle   NaN          NaN          NaN
# 3              NaN   NaN          NaN          NaN
# 4              NaN   NaN          NaN          NaN
# ..             ...   ...          ...          ...
# 225            NaN   NaN          NaN          NaN
# 226          Groin   NaN          NaN          NaN
# 227            NaN   NaN          NaN          NaN
# 228          Wrist   NaN          NaN          NaN
# 229          Wrist   NaN          NaN          NaN
#
# [230 rows x 16 columns]

# %%
player_dict_df = player_dictionary()

# %%
player_dict_df
# Out:
#       PERSON_ID DISPLAY_LAST_COMMA_FIRST   DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0         76001          Abdelnaby, Alaa       Alaa Abdelnaby             0
# 1         76002         Abdul-Aziz, Zaid      Zaid Abdul-Aziz             0
# 2         76003     Abdul-Jabbar, Kareem  Kareem Abdul-Jabbar             0
# 3            51      Abdul-Rauf, Mahmoud   Mahmoud Abdul-Rauf             0
# 4          1505       Abdul-Wahad, Tariq    Tariq Abdul-Wahad             0
# ...         ...                      ...                  ...           ...
# 4486    1627790              Zizic, Ante           Ante Zizic             1
# 4487      78647                Zoet, Jim             Jim Zoet             0
# 4488      78648               Zopf, Bill            Bill Zopf             0
# 4489    1627826             Zubac, Ivica          Ivica Zubac             1
# 4490      78650              Zunic, Matt           Matt Zunic             0
#
#       FROM_YEAR  TO_YEAR                   PLAYERCODE     TEAM_ID  TEAM_CITY  \
# 0          1990     1994       HISTADD_alaa_abdelnaby           0        NaN
# 1          1968     1977      HISTADD_zaid_abdul-aziz           0        NaN
# 2          1969     1988  HISTADD_kareem_abdul-jabbar           0        NaN
# 3          1990     2000           mahmoud_abdul-rauf           0        NaN
# 4          1997     2003            tariq_abdul-wahad           0        NaN
# ...         ...      ...                          ...         ...        ...
# 4486       2017     2019                   ante_zizic  1610612739  Cleveland
# 4487       1982     1982             HISTADD_jim_zoet           0        NaN
# 4488       1970     1970             HISTADD_zip_zopf           0        NaN
# 4489       2016     2019                  ivica_zubac  1610612746         LA
# 4490       1948     1948           HISTADD_matt_zunic           0        NaN
#
#       TEAM_NAME TEAM_ABBREVIATION  TEAM_CODE GAMES_PLAYED_FLAG  \
# 0           NaN               NaN        NaN                 Y
# 1           NaN               NaN        NaN                 Y
# 2           NaN               NaN        NaN                 Y
# 3           NaN               NaN        NaN                 Y
# 4           NaN               NaN        NaN                 Y
# ...         ...               ...        ...               ...
# 4486  Cavaliers               CLE  cavaliers                 Y
# 4487        NaN               NaN        NaN                 Y
# 4488        NaN               NaN        NaN                 Y
# 4489   Clippers               LAC   clippers                 Y
# 4490        NaN               NaN        NaN                 Y
#
#       OTHERLEAGUE_EXPERIENCE_CH
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 4486                          1
# 4487                          0
# 4488                          0
# 4489                          1
# 4490                          0
#
# [4491 rows x 14 columns]

# %%
roto_data = pd.read_csv('data/Roto_Data/roto_total_data.csv')

# %%
df = pd.Series(['Porter' in i for i in roto_data['LastName, FirstName'].unique()])
df[df == True]
# Out:
# 405    True
# 710    True
# dtype: bool

# %%
roto_data['LastName, FirstName'].unique()[405]
# Out:
# 'Porter, Otto'

# %%
def names_broken(names):
    return list(set(names) - set(player_dict_df['DISPLAY_FIRST_LAST'].unique()))

# %%
def name_fixed(name):
    return name in set(player_dict_df['DISPLAY_FIRST_LAST'].unique())

# %%
names_to_be_fixed = names_broken(fd_players['Nickname'].unique())
name_fixer = {}
for i in range(len(names_to_be_fixed)):
    copy_name = names_to_be_fixed[i]
    names_to_be_fixed[i] += ' Jr.'
    if name_fixed(names_to_be_fixed[i]):
        name_fixer[copy_name] = names_to_be_fixed[i]
        print(names_to_be_fixed[i])
names_to_be_fixed = names_broken(names_to_be_fixed)
for i in range(len(names_to_be_fixed)):
    copy_name = names_to_be_fixed[i].strip('Jr.').strip(' ')
    names_to_be_fixed[i] = copy_name.replace('.','')
    if name_fixed(names_to_be_fixed[i]):
        name_fixer[copy_name] = names_to_be_fixed[i]
        print(names_to_be_fixed[i])
names_to_be_fixed = names_broken(names_to_be_fixed)
names_to_be_fixed
# Out:
# Wendell Carter Jr.
# Danuel House Jr.
# Kelly Oubre Jr.
# Troy Brown Jr.
# Derrick Jones Jr.
# Otto Porter Jr.
# CJ Miles
# ['Lonnie Walker']

# %%
name_fixer['Lonnie Walker'] = 'Lonnie Walker IV'

# %%
name_fixer
# Out:
# {'Wendell Carter': 'Wendell Carter Jr.',
#  'Danuel House': 'Danuel House Jr.',
#  'Kelly Oubre': 'Kelly Oubre Jr.',
#  'Troy Brown': 'Troy Brown Jr.',
#  'Derrick Jones': 'Derrick Jones Jr.',
#  'Otto Porter': 'Otto Porter Jr.',
#  'C.J. Miles': 'CJ Miles',
#  'Lonnie Walker': 'Lonnie Walker IV'}

# %%
fd_players['Nickname'] = fd_players['Nickname'].replace(name_fixer)

# %%
player_dict_df
# Out:
#       PERSON_ID DISPLAY_LAST_COMMA_FIRST   DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0         76001          Abdelnaby, Alaa       Alaa Abdelnaby             0
# 1         76002         Abdul-Aziz, Zaid      Zaid Abdul-Aziz             0
# 2         76003     Abdul-Jabbar, Kareem  Kareem Abdul-Jabbar             0
# 3            51      Abdul-Rauf, Mahmoud   Mahmoud Abdul-Rauf             0
# 4          1505       Abdul-Wahad, Tariq    Tariq Abdul-Wahad             0
# ...         ...                      ...                  ...           ...
# 4486    1627790              Zizic, Ante           Ante Zizic             1
# 4487      78647                Zoet, Jim             Jim Zoet             0
# 4488      78648               Zopf, Bill            Bill Zopf             0
# 4489    1627826             Zubac, Ivica          Ivica Zubac             1
# 4490      78650              Zunic, Matt           Matt Zunic             0
#
#       FROM_YEAR  TO_YEAR                   PLAYERCODE     TEAM_ID  TEAM_CITY  \
# 0          1990     1994       HISTADD_alaa_abdelnaby           0        NaN
# 1          1968     1977      HISTADD_zaid_abdul-aziz           0        NaN
# 2          1969     1988  HISTADD_kareem_abdul-jabbar           0        NaN
# 3          1990     2000           mahmoud_abdul-rauf           0        NaN
# 4          1997     2003            tariq_abdul-wahad           0        NaN
# ...         ...      ...                          ...         ...        ...
# 4486       2017     2019                   ante_zizic  1610612739  Cleveland
# 4487       1982     1982             HISTADD_jim_zoet           0        NaN
# 4488       1970     1970             HISTADD_zip_zopf           0        NaN
# 4489       2016     2019                  ivica_zubac  1610612746         LA
# 4490       1948     1948           HISTADD_matt_zunic           0        NaN
#
#       TEAM_NAME TEAM_ABBREVIATION  TEAM_CODE GAMES_PLAYED_FLAG  \
# 0           NaN               NaN        NaN                 Y
# 1           NaN               NaN        NaN                 Y
# 2           NaN               NaN        NaN                 Y
# 3           NaN               NaN        NaN                 Y
# 4           NaN               NaN        NaN                 Y
# ...         ...               ...        ...               ...
# 4486  Cavaliers               CLE  cavaliers                 Y
# 4487        NaN               NaN        NaN                 Y
# 4488        NaN               NaN        NaN                 Y
# 4489   Clippers               LAC   clippers                 Y
# 4490        NaN               NaN        NaN                 Y
#
#       OTHERLEAGUE_EXPERIENCE_CH
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 4486                          1
# 4487                          0
# 4488                          0
# 4489                          1
# 4490                          0
#
# [4491 rows x 14 columns]

# %%
fd_players['Nickname'] = fd_players['Nickname'].replace(name_fixer)

# %%
set(fd_players['Nickname'].unique()) - set(player_dict_df['DISPLAY_FIRST_LAST'].unique())
# Out:
# set()

# %%
player_dict_df.merge(fd_players, left_on='DISPLAY_FIRST_LAST', right_on='Nickname')
# Out:
#      PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0       203500            Adams, Steven       Steven Adams             1
# 1      1628389             Adebayo, Bam        Bam Adebayo             1
# 2       200746       Aldridge, LaMarcus  LaMarcus Aldridge             1
# 3      1628960           Allen, Grayson      Grayson Allen             1
# 4       203937           Anderson, Kyle      Kyle Anderson             1
# ..         ...                      ...                ...           ...
# 225    1626159         Winslow, Justise    Justise Winslow             1
# 226    1626174          Wood, Christian     Christian Wood             1
# 227    1626153            Wright, Delon       Delon Wright             1
# 228     201152          Young, Thaddeus     Thaddeus Young             1
# 229    1627790              Zizic, Ante         Ante Zizic             1
#
#      FROM_YEAR  TO_YEAR         PLAYERCODE     TEAM_ID      TEAM_CITY  \
# 0         2013     2019       steven_adams  1610612760  Oklahoma City
# 1         2017     2019        bam_adebayo  1610612748          Miami
# 2         2006     2019  lamarcus_aldridge  1610612759    San Antonio
# 3         2018     2019      grayson_allen  1610612763        Memphis
# 4         2014     2019      kyle_anderson  1610612763        Memphis
# ..         ...      ...                ...         ...            ...
# 225       2015     2019    justise_winslow  1610612748          Miami
# 226       2015     2019     christian_wood  1610612765        Detroit
# 227       2015     2019       delon_wright  1610612742         Dallas
# 228       2007     2019     thaddeus_young  1610612741        Chicago
# 229       2017     2019         ante_zizic  1610612739      Cleveland
#
#      TEAM_NAME  ... Played Salary     Game  Team Opponent Injury Indicator  \
# 0      Thunder  ...     22   7000  CHI@OKC   OKC      CHI              NaN
# 1         Heat  ...     26   9300  MIA@MEM   MIA      MEM              NaN
# 2        Spurs  ...     23   7700   SA@HOU    SA      HOU              NaN
# 3    Grizzlies  ...     13   3800  MIA@MEM   MEM      MIA                O
# 4    Grizzlies  ...     20   3700  MIA@MEM   MEM      MIA              NaN
# ..         ...  ...    ...    ...      ...   ...      ...              ...
# 225       Heat  ...     10   5400  MIA@MEM   MIA      MEM                O
# 226    Pistons  ...     24   3800  WAS@DET   DET      WAS              NaN
# 227  Mavericks  ...     23   4300  DAL@MIL   DAL      MIL              NaN
# 228      Bulls  ...     27   4000  CHI@OKC   CHI      OKC              NaN
# 229  Cavaliers  ...      9   3500  CLE@TOR   CLE      TOR              NaN
#
#     Injury Details Tier Unnamed: 14  Unnamed: 15
# 0              NaN  NaN         NaN          NaN
# 1              NaN  NaN         NaN          NaN
# 2              NaN  NaN         NaN          NaN
# 3            Ankle  NaN         NaN          NaN
# 4              NaN  NaN         NaN          NaN
# ..             ...  ...         ...          ...
# 225           Back  NaN         NaN          NaN
# 226            NaN  NaN         NaN          NaN
# 227            NaN  NaN         NaN          NaN
# 228            NaN  NaN         NaN          NaN
# 229            NaN  NaN         NaN          NaN
#
# [230 rows x 30 columns]
